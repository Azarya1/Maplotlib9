# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.5.2
# 1.21.5

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
x = np.linspace(1, 10, 15)
           
plt.plot(x, x, 'bs-', label = 'lin')
plt.plot(x, np.log(x), 'ro-', label = 'log')

plt.legend()
plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %%
plt.style.use('./style_ku.mplstyle')

# %%
x = np.Linspace(1, 18, 15)

 

plt.plot(x, x, 'bs-', label='Lin')
plt.plot(x, np.log(x), 'ro-', label=" log" )

put. Legend()
plt.xlabel( 'Sumbu Z')
plt.ylabel( 'Sumbu Y)
plt.title( 'Contoh Plot')

plt.show()

# %%
plt.style.use('[seaborn', 'dark_background'])

# %%
X = np. linspace(1, 18, 15)

plt.plot(x, x, 'bs-', label= 'lin')
plt.plot(x, np.log(x), 'ro-', label= 'log')

plt.legend()
p;t.xlabel('Sumbuh')
plt.ylabel('Jumlah')
plt.tittle('Contoh Bar Plot')

plt.show( )

# %%
Ut. style. use( ‘ggplot’)

pLL.plot(np.sin(np.linspace(0, 2 * np.pi)), 'r-o'
plt-show()

# %%
with plt.style.context( 'dark_background'):
    plt.plot(np.sin(np.linspace(0, 2* np.pi)), 'r-0')

plt.show()

# %%
plt.plot(np.sin(np.linspace(0, 2* np.pi)), 'r-0')
pLt.show( )
